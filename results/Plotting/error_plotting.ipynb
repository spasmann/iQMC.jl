# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data1Sobol = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTab1Sobol(6-6, -5).dat")
dataInfSobol = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabInfSobol(6-6, -5).dat")
data1Random = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTab1Random(6-6, -5).dat")
dataInfRandom = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabInfRandom(6-6, -5).dat")

Nvals = np.array((2**10, 2**11, 2**12, 2**13, 2**14, 2**15))
NxVals = 50*np.array([1, 2, 4, 8, 16, 32])
table = pd.DataFrame(data1Sobol, columns = Nvals, index = NxVals)
print("**************************** S = 1.0 ****************************")
print(table)
table = pd.DataFrame(dataInfSobol, columns = Nvals, index = NxVals)
print("**************************** S = Inf ****************************")
print(table)
# Out:
# **************************** S = 1.0 ****************************
#          1024      2048      4096      8192      16384     32768
# 50    0.131716  0.134158  0.134964  0.135141  0.135038  0.135098
# 100   0.060963  0.063475  0.064455  0.064697  0.064641  0.064680
# 200   0.037722  0.031139  0.031031  0.031538  0.031452  0.031526
# 400   0.026321  0.014393  0.015062  0.015465  0.015468  0.015543
# 800   0.023949  0.009405  0.007073  0.007809  0.007627  0.007688
# 1600  0.041628  0.009402  0.004547  0.006996  0.003747  0.003797
# **************************** S = Inf ****************************
#          1024      2048      4096      8192      16384     32768
# 50    0.036377  0.023075  0.008534  0.009926  0.010153  0.010808
# 100   0.031602  0.014452  0.005456  0.004231  0.004428  0.005182
# 200   0.035736  0.013830  0.005147  0.002986  0.001972  0.002247
# 400   0.042218  0.015981  0.006291  0.003732  0.001380  0.000912
# ...

# %%
plt.figure(dpi=300, figsize=(10,10))
plt.suptitle("Garcia Relative Error")

ylim = [10**(-3.5), 10**(-0.1)]
ylabel = r'$||\frac{\psi_i - \psi}{\psi}||_\infty$'

#########################################################
#########################################################

data = data1Sobol
diagonal = np.diag(data)
Nx50 = data[0,:]
Nx100 = data[1,:]
Nx200 = data[2,:]
Nx400 = data[3,:]
Nx800 = data[4,:]
Nx1600 = data[5,:]
O = diagonal[0]*(Nvals[0])/(Nvals)

plt.subplot(221)
plt.title(r"QMC $(s=1.0)$")
plt.ylabel(ylabel)
plt.xlabel("N")
plt.plot(Nvals, diagonal, 'k--',label=r'$N_x(n)=25*2^{n}$')
plt.plot(Nvals, Nx200, '*-',label=r'$N_x=200$')
plt.plot(Nvals, Nx400, '^-',label=r'$N_x=400$')
plt.plot(Nvals, Nx800, 's-',label=r'$N_x=800$')
plt.plot(Nvals, O,label = r'$O(N^{-1})$')
plt.xscale('log')
plt.yscale('log')
plt.ylim(ylim)
plt.legend(loc='lower left')
plt.tight_layout()

#########################################################
#########################################################

data = data1Random
diagonal = np.diag(data)
Nx50 = data[0,:]
Nx100 = data[1,:]
Nx200 = data[2,:]
Nx400 = data[3,:]
Nx800 = data[4,:]
Nx1600 = data[5,:]
O = diagonal[0]*np.sqrt(Nvals[0]/Nvals)

plt.subplot(222)
plt.title(r"MC $(s=1.0)$")
plt.ylabel(ylabel)
plt.xlabel("N")
#plt.plot(Nvals, diagonal, 'k--',label=r'$N_x(n)=25*2^{n}$')
plt.plot(Nvals, Nx200, '*-',label=r'$N_x=200$')
plt.plot(Nvals, Nx400, '^-',label=r'$N_x=400$')
plt.plot(Nvals, Nx800, 's-',label=r'$N_x=800$')
plt.plot(Nvals, O,label = r'$O(N^{-1/2})$')
plt.xscale('log')
plt.yscale('log')
plt.ylim(ylim)
plt.legend(loc='lower left')
plt.tight_layout()

#########################################################
#########################################################

data = dataInfSobol
diagonal = np.diag(data)
Nx50 = data[0,:]
Nx100 = data[1,:]
Nx200 = data[2,:]
Nx400 = data[3,:]
Nx800 = data[4,:]
Nx1600 = data[5,:]
O = diagonal[0]*(Nvals[0])/(Nvals)

plt.subplot(223)
plt.title(r"QMC $(s=\infty)$")
plt.ylabel(ylabel)
plt.xlabel("N")
#plt.plot(Nvals, diagonal, 'k--',label=r'$N_x(n)=25*2^{n}$')
plt.plot(Nvals, Nx200, '*-',label=r'$N_x=200$')
plt.plot(Nvals, Nx400, '^-',label=r'$N_x=400$')
plt.plot(Nvals, Nx800, 's-',label=r'$N_x=800$')
plt.plot(Nvals, O,label = r'$O(N^{-1})$')
plt.xscale('log')
plt.yscale('log')
plt.ylim(ylim)
plt.legend(loc='lower left')
plt.tight_layout()

#########################################################
#########################################################

data = dataInfRandom
diagonal = np.diag(data)
Nx50 = data[0,:]
Nx100 = data[1,:]
Nx200 = data[2,:]
Nx400 = data[3,:]
Nx800 = data[4,:]
Nx1600 = data[5,:]
O = diagonal[0]*np.sqrt(Nvals[0]/Nvals)

plt.subplot(224)
plt.title(r"MC $(s=\infty)$")
plt.ylabel(ylabel)
plt.xlabel("N")
#plt.plot(Nvals, diagonal, 'k--',label=r'$N_x(n)=25*2^{n}$')
plt.plot(Nvals, Nx200, '*-',label=r'$N_x=200$')
plt.plot(Nvals, Nx400, '^-',label=r'$N_x=400$')
plt.plot(Nvals, Nx800, 's-',label=r'$N_x=800$')
plt.plot(Nvals, O,label = r'$O(N^{-1/2})$')
plt.xscale('log')
plt.yscale('log')
plt.ylim(ylim)
plt.legend(loc='lower left')
plt.tight_layout()

# %%
mgSobol = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabMgSobol(6-6, -5).dat")
mgRandom = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabMgRandom(6-6, -5).dat")
table = pd.DataFrame(mgSobol, columns = Nvals, index = NxVals)
print("**************************** MultiGroup ****************************")
print(table)
table = pd.DataFrame(mgRandom, columns = Nvals, index = NxVals)
print("**************************** MultiGroup ****************************")
print(table)
# Out:
# **************************** MultiGroup ****************************
#           1024      2048      4096      8192      16384     32768
# 50     0.074472  0.056613  0.028927  0.020458  0.004391  0.001776
# 100    0.147123  0.111852  0.055687  0.042075  0.006965  0.004414
# 200    0.286663  0.138702  0.087745  0.057144  0.015567  0.008651
# 400    0.591653  0.236821  0.150866  0.090128  0.028441  0.013228
# 800    2.295230  0.559149  0.259410  0.138284  0.050785  0.029494
# 1600  78.628626  2.289950  0.596488  0.248526  0.107215  0.049814
# **************************** MultiGroup ****************************
#          1024      2048      4096      8192      16384     32768
# 50    0.168548  0.161692  0.210422  0.069927  0.063888  0.035520
# 100   0.259215  0.251035  0.240267  0.073218  0.086407  0.059083
# 200   0.291100  0.315398  0.285752  0.090432  0.090953  0.068549
# 400   0.534420  0.376160  0.350271  0.126014  0.097599  0.074759
# ...

# %%
plt.figure(dpi=300, figsize=(10,5))
plt.suptitle("MultiGroup Relative Error")
ylabel = r'$||\frac{\phi_i - \phi}{\phi}||_\infty$'
ylim = [10**(-3), 10**(2)]

####################################################
data = mgSobol
diagonal = np.diag(mgRandom)
Nx50 = data[0,:]
Nx100 = data[1,:]
Nx200 = data[2,:]
Nx400 = data[3,:]
Nx800 = data[4,:]
Nx1600 = data[5,:]
O = Nx200[0]*(Nvals[0])/(Nvals)

plt.subplot(121)
plt.title("QMC")
plt.ylabel(ylabel)
plt.xlabel("N")
#plt.plot(Nvals, diagonal, 'k--',label=r'$Nx(n)=25*2^{n}$')
plt.plot(Nvals, Nx50, '*-',label=r'Nx=50')
plt.plot(Nvals, Nx200, '^-',label=r'Nx=200')
plt.plot(Nvals, Nx1600, 's-',label=r'Nx=1600')
plt.plot(Nvals, O, label = r'$O(N^{-1})$')
plt.xscale('log')
plt.yscale('log')
plt.ylim(ylim)
plt.tight_layout()
plt.legend()

####################################################
data = mgRandom
diagonal = np.diag(mgRandom)
Nx50 = data[0,:]
Nx100 = data[1,:]
Nx200 = data[2,:]
Nx400 = data[3,:]
Nx800 = data[4,:]
Nx1600 = data[5,:]
O = Nx200[0]*np.sqrt(Nvals[0]/Nvals)

plt.subplot(122)
plt.title("MC")
plt.ylabel(ylabel)
plt.xlabel("N")
#plt.plot(Nvals, diagonal, 'k--',label=r'$Nx(n)=25*2^{n}$')
plt.plot(Nvals, Nx50, '*-',label=r'Nx=50')
plt.plot(Nvals, Nx200, '^-',label=r'Nx=200')
plt.plot(Nvals, Nx1600, 's-',label=r'Nx=1600')
plt.plot(Nvals, O, label = r'$O(N^{-1/2})$')
plt.xscale('log')
plt.yscale('log')
plt.ylim(ylim)
plt.tight_layout()
plt.legend()

# %%
dataSobol = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedSobol(6-6, -5).dat")
dataRandom = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedRandom(6-6, -5).dat")


NxVals = 32*np.array([1, 2, 4, 8, 16, 32])

table = pd.DataFrame(dataSobol, columns = Nvals, index = NxVals)
print("**************************** Reeds Sobol ****************************")
print(table)
table = pd.DataFrame(dataRandom, columns = Nvals, index = NxVals)
print("**************************** Reeds Random ****************************")
print(table)
# Out:
# **************************** Reeds Sobol ****************************
#          1024      2048      4096      8192      16384     32768
# 32    0.241641  0.126103  0.066652  0.043596  0.062751  0.040107
# 64    0.499851  0.252753  0.134643  0.085747  0.052609  0.034814
# 128   0.973935  0.483159  0.256688  0.156291  0.095691  0.062496
# 256   1.569487  0.774025  0.408706  0.240454  0.147806  0.095444
# 512   2.083570  1.026084  0.539463  0.311372  0.192047  0.123337
# 1024  3.615742  1.874263  0.724668  0.358506  0.221556  0.141976
# **************************** Reeds Random ****************************
#          1024      2048      4096      8192      16384     32768
# 32    0.434961  0.963072  0.605663  0.257053  0.336604  0.090698
# 64    0.615736  1.489293  0.619873  0.335495  0.358244  0.127249
# 128   0.891384  2.115139  0.644998  0.384281  0.358981  0.144294
# 256   1.391769  2.563594  0.945760  0.450563  0.392908  0.207686
# ...

# %%
plt.figure(dpi=300,figsize=(10,5))
ylabel = r'$||\phi_i - \phi||_\infty$'
ylim = [10**(-2), 10**(1)]
plt.suptitle("Reeds Error")

####################################################
data = dataSobol
diagonal = np.diag(data)
Nx32 = data[0,:]
Nx64 = data[1,:]
Nx128 = data[2,:]
Nx256 = data[3,:]
Nx512 = data[4,:]
Nx1024 = data[5,:]
O = (Nx1024[0]*(Nvals[0])/(Nvals))

plt.subplot(121)
plt.title("QMC")
plt.ylabel(ylabel)
plt.xlabel("N")
plt.plot(Nvals, Nx64, '*-',label=r'Nx=64')
plt.plot(Nvals, Nx256, '^-',label=r'Nx=256')
plt.plot(Nvals, Nx1024, 's-',label=r'Nx=1024')
plt.plot(Nvals, O, label = r'$O(N^{-1})$')
plt.xscale('log')
plt.yscale('log')
plt.tight_layout()
plt.ylim(ylim)
plt.legend()

####################################################

data = dataRandom
diagonal = np.diag(data)
Nx32 = data[0,:]
Nx64 = data[1,:]
Nx128 = data[2,:]
Nx256 = data[3,:]
Nx512 = data[4,:]
Nx1024 = data[5,:]
O = Nx256[0]*np.sqrt(Nvals[0]/Nvals) 

plt.subplot(122)
plt.title("MC")
plt.ylabel(ylabel)
plt.xlabel("N")
#plt.plot(Nvals, diagonal, 'k--',label=r'$Nx(n)=16*2^{n}$')
plt.plot(Nvals, Nx64, '*-',label=r'Nx=64')
plt.plot(Nvals, Nx256, '^-',label=r'Nx=256')
plt.plot(Nvals, Nx1024, 's-',label=r'Nx=1024')
plt.plot(Nvals, O, label = r'$O(N^{-1/2})$')
plt.xscale('log')
plt.yscale('log')
plt.tight_layout()
plt.ylim(ylim)
plt.legend()

# %%
dataSobol = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedSobol(1-8, -5)Nx1024.dat")
dataRandom = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedRandom(1-8, -5)Nx1024.dat")
dataHalton = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedHalton(1-8, -5)Nx1024.dat")
dataGolden = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedGolden(1-8, -5)Nx1024.dat")

dataSobol2 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedSobol(1-5, -5).dat")
dataRandom2 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedRandom(1-5, -5).dat")
dataHalton2 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedHalton(1-5, -5).dat")
dataGolden2 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedGolden(1-5, -5).dat")


NxVals = 32*np.array([32])
NxVals2 = 32*np.array([64])
Nvals = np.array((2**10, 2**11, 2**12, 2**13, 2**14, 2**15, 2**16, 2**17))
Nvals2 = np.array((2**15, 2**16, 2**17, 2**18, 2**19))


"""
table = pd.DataFrame(dataSobol, columns = Nvals, index = NxVals)
print("**************************** Reeds Sobol ****************************")
print(table)
table = pd.DataFrame(dataRandom, columns = Nvals, index = NxVals)
print("**************************** Reeds Random ****************************")
print(table)
table = pd.DataFrame(dataHalton, columns = Nvals, index = NxVals)
print("**************************** Reeds Halton ****************************")
print(table)
table = pd.DataFrame(dataGolden, columns = Nvals, index = NxVals)
print("**************************** Reeds Golden ****************************")
print(table)
"""
print(dataSobol)
# Out:
# [3.6157421  1.87426348 0.72466755 0.35850623 0.22155607 0.14197576
#  0.13262278 0.12543925]

# %%
plt.figure(dpi=300)
ylabel = r'$||\phi_i - \phi||_\infty$'
ylim = [10**(-3), 10**(1)]
plt.title("Reed's Error")

####################################################
O = (dataSobol[0]*(Nvals[0]/Nvals))

#plt.plot(Nvals, dataSobol, '*-',label=r'$N_x=1024$')
plt.plot(Nvals, O, label = r'$O(N^{-1})$')
#plt.plot(Nvals, dataRandom, '^-',label='Random')
plt.plot(Nvals, dataHalton, 's-',label='Halton')
#plt.plot(Nvals, dataGolden, 'o-',label='Golden')

#plt.plot(Nvals2, dataSobol2, '*-',label=r'$N_x=2048$')
#plt.plot(Nvals2, O, label = r'$O(N^{-1})$')
#plt.plot(Nvals2, dataRandom2, '^-',label='Random')
plt.plot(Nvals2, dataHalton2, 's-',label='Halton')
#plt.plot(Nvals2, dataGolden2, 'o-',label='Golden')

####################################################
plt.ylabel(ylabel)
plt.xlabel("N")
plt.xscale('log')
plt.yscale('log')
plt.tight_layout()
plt.ylim(ylim)
plt.legend()

# %%
Sobol80 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedSobol(1-11, -5)Nx80MCDC.dat")
Halton80 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedHalton(1-8, -5)Nx80MCDC.dat")
Golden80 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedGolden(1-8, -5)Nx80MCDC.dat")
Random80 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedRandom(1-11, -5)Nx80MCDC.dat")
Sobol80 = Sobol80[:8]
Random80 = Random80[:8]
Nvals = np.array((2**10, 2**11, 2**12, 2**13, 2**14, 2**15, 2**16, 2**17))

# %%
plt.figure(dpi=300,figsize=(5,5))
ylabel = r'$||\phi_i - \phi||_\infty$'
ylim = [10**(-3), 10**(1)]
plt.title(r"LDS Comparison")

####################################################
O = (Random80[0]*np.sqrt(Nvals[0]/Nvals))
O2 = (Sobol80[0]*(Nvals[0]/Nvals))

plt.plot(Nvals, O, 'k-', label = r'$O(N^{-1/2})$')
plt.plot(Nvals, O2, 'k--', label = r'$O(N^{-1})$')
plt.plot(Nvals, Sobol80, 'o-',label=r'Sobol')
plt.plot(Nvals, Halton80, 's-',label=r'Halton')
plt.plot(Nvals, Golden80, '^-',label=r'Golden')
plt.plot(Nvals, Random80, '*-',label=r'Random')

####################################################
plt.ylabel(ylabel)
plt.xlabel("N")
plt.xscale('log')
plt.yscale('log')
plt.tight_layout()
plt.ylim(ylim)
plt.legend()
plt.tight_layout()

# %%
Sobol80 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedSobol(1-11, -5)Nx80MCDC.dat")
Sobol160 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedSobol(1-11, -5)Nx160MCDC.dat")
Sobol320 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedSobol(1-11, -5)Nx320MCDC.dat")

Random80 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedRandom(1-11, -5)Nx80MCDC.dat")
Random160 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedRandom(1-11, -5)Nx160MCDC.dat")
Random320 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedRandom(1-11, -5)Nx320MCDC.dat")

# %%
Nvals = np.array((2**10, 2**11, 2**12, 2**13, 2**14, 2**15, 2**16, 2**17, 2**18, 2**19))
n = len(Nvals)

plt.figure(dpi=300,figsize=(10,5))
ylabel = r'$||\phi_i - \phi||_\infty$'
ylim = [10**(-4), 10**(1)]
plt.suptitle(r"Reed's Error")

####################################################
plt.subplot(121)

O = (Sobol80[0]*(Nvals[0]/Nvals))
plt.plot(Nvals, O[:n], label = r'$O(N^{-1})$')
plt.plot(Nvals, Sobol80[:n], 'o-',label=r'$N_x=80$')
plt.plot(Nvals, Sobol160[:n], 's-',label=r'$N_x=160$')
plt.plot(Nvals, Sobol320[:n], '^-',label=r'$N_x=320$')
plt.title("QMC")
plt.ylabel(ylabel)
plt.xlabel("N")
plt.xscale('log')
plt.yscale('log')
plt.tight_layout()
plt.ylim(ylim)
plt.legend()

####################################################
plt.subplot(122)

O = (Random80[0]*np.sqrt(Nvals[0]/Nvals))
plt.plot(Nvals, O[:n], label = r'$O(N^{-1/2})$')
plt.plot(Nvals, Random80[:n], 'o-',label=r'$N_x=80$')
plt.plot(Nvals, Random160[:n], 's-',label=r'$N_x=160$')
plt.plot(Nvals, Random320[:n], '^-',label=r'$N_x=320$')
plt.title("MC")
plt.ylabel(ylabel)
plt.xlabel("N")
plt.xscale('log')
plt.yscale('log')
plt.tight_layout()
plt.ylim(ylim)
plt.legend()

# %%
Sobol80 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Reeds/ErrTabReedSobol(1-8, -5)Nx80Analytic.dat")
Sobol160 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Reeds/ErrTabReedSobol(1-8, -5)Nx160Analytic.dat")

#Random160 = np.genfromtxt("/Users/sampasmann/Documents/GitHub/Krylov_QMC/Examples/Data/ErrTabReedRandom(1-8, -5)Nx160.dat")

Nvals = np.array((2**10, 2**11, 2**12, 2**13, 2**14, 2**15, 2**16, 2**17))

plt.figure(dpi=300,figsize=(10,5))
ylabel = r'$||\phi_i - \phi||_\infty$'
ylim = [10**(-3), 10**(1)]
plt.suptitle(r"Reed's Error - Analytic")

####################################################
plt.subplot(121)

O = (Sobol80[0]*(Nvals[0]/Nvals))
plt.plot(Nvals, O, label = r'$O(N^{-1})$')
plt.plot(Nvals, Sobol80, 'o',label=r'$N_x=80$')
plt.plot(Nvals, Sobol160, 's',label=r'$N_x=160$')
#plt.plot(Nvals, Sobol320, '^',label=r'$N_x=320$')
plt.title("QMC")
plt.ylabel(ylabel)
plt.xlabel("N")
plt.xscale('log')
plt.yscale('log')
plt.tight_layout()
plt.ylim(ylim)
plt.legend()

####################################################
plt.subplot(122)

O = (Random80[0]*np.sqrt(Nvals[0]/Nvals))
plt.plot(Nvals, O, label = r'$O(N^{-1/2})$')
#plt.plot(Nvals, Random80, 'o',label=r'$N_x=80$')
#plt.plot(Nvals, Random160, 's',label=r'$N_x=160$')
plt.title("MC")
plt.ylabel(ylabel)
plt.xlabel("N")
plt.xscale('log')
plt.yscale('log')
plt.tight_layout()
plt.ylim(ylim)
plt.legend()
